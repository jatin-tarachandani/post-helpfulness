# %%
import sys

from datetime import datetime

from keras import backend as K
from keras.models import Sequential, Model
from keras.layers import Input, Dense, Dropout, GRU, Lambda, concatenate
from keras.layers import Embedding
import keras.preprocessing as preprocessing
import keras.layers as layers

import numpy as np
import pandas as pd

from sklearn import model_selection

import constants
import utilities
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29204\2166179551.py in <module>
#       3 from datetime import datetime
#       4
# ----> 5 from keras import backend as K
#       6 from keras.models import Sequential, Model
#       7 from keras.layers import Input, Dense, Dropout, GRU, Lambda, concatenate
#
# c:\ProgramData\Anaconda3\lib\site-packages\keras\__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras import __internal__
#       4 from keras import activations
#       5 from keras import applications
#
# c:\ProgramData\Anaconda3\lib\site-packages\keras\__internal__\__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras.__internal__ import backend
#       4 from keras.__internal__ import layers
#       5 from keras.__internal__ import losses
#
# c:\ProgramData\Anaconda3\lib\site-packages\keras\__internal__\backend\__init__.py in <module>
#       1 """AUTOGENERATED. DO NOT EDIT."""
#       2
# ----> 3 from keras.src.backend import _initialize_variables as initialize_variables
#       4 from keras.src.backend import track_variable
#
# c:\ProgramData\Anaconda3\lib\site-packages\keras\src\__init__.py in <module>
#      19 """
#      20 from keras.src import distribute
# ---> 21 from keras.src import models
#      22 from keras.src.engine.input_layer import Input
#      23 from keras.src.engine.sequential import Sequential
#
# c:\ProgramData\Anaconda3\lib\site-packages\keras\src\models\__init__.py in <module>
#      16
#      17
# ---> 18 from keras.src.engine.functional import Functional
#      19 from keras.src.engine.sequential import Sequential
#      20 from keras.src.engine.training import Model
#
# c:\ProgramData\Anaconda3\lib\site-packages\keras\src\engine\functional.py in <module>
#      21 import warnings
#      22
# ---> 23 import tensorflow.compat.v2 as tf
#      24
#      25 from keras.src import backend
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29204\210722109.py in <module>
#       1 strin = "This is the string of the values obtained from the \% of the data, including all the content of cats, all the content of the dog and the man being inside the box. Why is he inside the box? is it because he is sleepy!"
#       2
# ----> 3 print(strin.values.astype(str))
#
# AttributeError: 'str' object has no attribute 'values'
